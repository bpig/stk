# %%
# %load_ext autoreload
# %autoreload 2
from today_market import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sub = get_today()
sub
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/urllib3/response.py:737, in HTTPResponse._error_catcher(self)
#     736 try:
# --> 737     yield
#     739 except SocketTimeout as e:
#     740     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     741     # there is yet no clean way to get at it from this context.
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/urllib3/response.py:862, in HTTPResponse._raw_read(self, amt, read1)
#     861 with self._error_catcher():
# --> 862     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     863     if amt is not None and amt != 0 and not data:
#     864         # Platform-specific: Buggy versions of Python.
#     865         # Close the connection when no data is returned
#    (...)
#     870         # not properly close the connection in all cases. There is
#     871         # no harm in redundantly calling close.
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/urllib3/response.py:845, in HTTPResponse._fp_read(self, amt, read1)
#     843 else:
#     844     # StringIO doesn't like amt=None
# --> 845     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~/anaconda3/envs/py310/lib/python3.10/http/client.py:466, in HTTPResponse.read(self, amt)
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#
# File ~/anaconda3/envs/py310/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     704 try:
# --> 705     return self._sock.recv_into(b)
#     706 except timeout:
#
# TimeoutError: timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     815 try:
# --> 816     yield from self.raw.stream(chunk_size, decode_content=True)
#     817 except ProtocolError as e:
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/urllib3/response.py:1043, in HTTPResponse.stream(self, amt, decode_content)
#    1042 while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1043     data = self.read(amt=amt, decode_content=decode_content)
#    1045     if data:
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/urllib3/response.py:935, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     933         return self._decoded_buffer.get(amt)
# --> 935 data = self._raw_read(amt)
#     937 flush_decoder = amt is None or (amt != 0 and not data)
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/urllib3/response.py:861, in HTTPResponse._raw_read(self, amt, read1)
#     859 fp_closed = getattr(self._fp, "closed", False)
# --> 861 with self._error_catcher():
#     862     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#
# File ~/anaconda3/envs/py310/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/urllib3/response.py:742, in HTTPResponse._error_catcher(self)
#     739 except SocketTimeout as e:
#     740     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     741     # there is yet no clean way to get at it from this context.
# --> 742     raise ReadTimeoutError(self._pool, None, "Read timed out.") from e  # type: ignore[arg-type]
#     744 except BaseSSLError as e:
#     745     # FIXME: Is there a better way to differentiate between SSLErrors?
#
# ReadTimeoutError: HTTPConnectionPool(host='127.0.0.1', port=1087): Read timed out.
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 sub = get_today()
#       2 sub
#
# File ~/code/stk/efin/today_market.py:23, in get_today(today)
#      20     print(f"read cached {fname}")
#      21     return pd.read_parquet(fname)
# ---> 23 df = ef.stock.get_realtime_quotes()
#      24 # for new column map
#      25 ori_columns = ['股票代码', '股票名称', '涨跌幅',
#      26                '最新价', '最高', '最低', '今开',
#      27                '涨跌额', '换手率', '量比', '动态市盈率',
#      28                '成交量', '成交额', '昨日收盘', '总市值', '流通市值',
#      29                '行情ID', '市场类型', '更新时间', '最新交易日']
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/efinance/utils/__init__.py:336, in process_dataframe_and_series.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     334 @wraps(func)
#     335 def wrapper(*args, **kwargs):
# --> 336     values = func(*args, **kwargs)
#     337     if isinstance(values, pd.DataFrame):
#     338         for column, function_name in function_fields.items():
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/efinance/utils/__init__.py:48, in to_numeric.<locals>.run(*args, **kwargs)
#      46 @wraps(func)
#      47 def run(*args, **kwargs):
# ---> 48     values = func(*args, **kwargs)
#      49     if isinstance(values, pd.DataFrame):
#      50         for column in values.columns:
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/efinance/stock/getter.py:433, in get_realtime_quotes(fs, **kwargs)
#     431         fs_list.append(FS_DICT["stock"])
#     432 fs_str = ",".join(fs_list)
# --> 433 df = get_realtime_quotes_by_fs(fs_str, **kwargs)
#     434 df.rename(columns={"代码": "股票代码", "名称": "股票名称"}, inplace=True)
#     436 return df
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/efinance/utils/__init__.py:48, in to_numeric.<locals>.run(*args, **kwargs)
#      46 @wraps(func)
#      47 def run(*args, **kwargs):
# ---> 48     values = func(*args, **kwargs)
#      49     if isinstance(values, pd.DataFrame):
#      50         for column in values.columns:
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/efinance/common/getter.py:79, in get_realtime_quotes_by_fs(fs, **kwargs)
#      77 with ThreadPoolExecutor() as executor:
#      78     tasks = executor.map(get_by_page, range(1, pages + 1), [pz] * pages)
# ---> 79     responses = list(tasks)
#      81 dfs = [
#      82     pd.DataFrame(response["data"]["diff"])[list(columns.keys())]
#      83     for response in responses
#      84 ]
#      85 df = (
#      86     pd.concat(dfs, axis=0, ignore_index=True)
#      87     .rename(columns=columns)[columns.values()]
#    (...)
#      93     )
#      94 )
#
# File ~/anaconda3/envs/py310/lib/python3.10/concurrent/futures/_base.py:621, in Executor.map.<locals>.result_iterator()
#     618 while fs:
#     619     # Careful not to keep a reference to the popped future
#     620     if timeout is None:
# --> 621         yield _result_or_cancel(fs.pop())
#     622     else:
#     623         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~/anaconda3/envs/py310/lib/python3.10/concurrent/futures/_base.py:319, in _result_or_cancel(***failed resolving arguments***)
#     317 try:
#     318     try:
# --> 319         return fut.result(timeout)
#     320     finally:
#     321         fut.cancel()
#
# File ~/anaconda3/envs/py310/lib/python3.10/concurrent/futures/_base.py:458, in Future.result(self, timeout)
#     456     raise CancelledError()
#     457 elif self._state == FINISHED:
# --> 458     return self.__get_result()
#     459 else:
#     460     raise TimeoutError()
#
# File ~/anaconda3/envs/py310/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File ~/anaconda3/envs/py310/lib/python3.10/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/efinance/common/getter.py:55, in get_realtime_quotes_by_fs.<locals>.get_by_page(pn, pz)
#      42 params = (
#      43     ("pn", pn),
#      44     ("pz", pz),
#    (...)
#      52     ("fields", fields),
#      53 )
#      54 url = "http://push2.eastmoney.com/api/qt/clist/get"
# ---> 55 json_response = session.get(
#      56     url, headers=EASTMONEY_REQUEST_HEADERS, params=params
#      57 ).json()
#      58 return json_response
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/efinance/shared/__init__.py:14, in CustomedSession.request(self, *args, **kwargs)
#      12 def request(self, *args, **kwargs):
#      13     kwargs.setdefault("timeout", 180)  # 3min
# ---> 14     return super(CustomedSession, self).request(*args, **kwargs)
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/requests/sessions.py:747, in Session.send(self, request, **kwargs)
#     744         pass
#     746 if not stream:
# --> 747     r.content
#     749 return r
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/requests/models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/requests/models.py:822, in Response.iter_content.<locals>.generate()
#     820     raise ContentDecodingError(e)
#     821 except ReadTimeoutError as e:
# --> 822     raise ConnectionError(e)
#     823 except SSLError as e:
#     824     raise RequestsSSLError(e)
#
# ConnectionError: HTTPConnectionPool(host='127.0.0.1', port=1087): Read timed out.

# %%
one = ef.stock.get_quote_history('601086')
one
# Out:
#       股票名称    股票代码          日期    开盘    收盘    最高    最低     成交量          成交额  \
# 0     国芳集团  601086  2017-09-29  2.39  3.15  3.15  2.39     493     221954.0
# 1     国芳集团  601086  2017-10-09  3.61  3.61  3.61  3.61     349     174839.0
# 2     国芳集团  601086  2017-10-10  4.11  4.11  4.11  4.11     196     107996.0
# 3     国芳集团  601086  2017-10-11  4.66  4.66  4.66  4.66     217     131502.0
# 4     国芳集团  601086  2017-10-12  5.27  5.27  5.27  5.27     682     455174.0
# ...    ...     ...         ...   ...   ...   ...   ...     ...          ...
# 1821  国芳集团  601086  2025-04-08  6.34  6.34  6.34  6.34   65748   41684232.0
# 1822  国芳集团  601086  2025-04-09  6.97  6.97  6.97  6.97   52318   36465646.0
# 1823  国芳集团  601086  2025-04-10  7.67  7.67  7.67  7.67  246827  189316041.0
# 1824  国芳集团  601086  2025-04-11  8.44  8.44  8.44  8.44   81569   68844236.0
# 1825  国芳集团  601086  2025-04-14  8.44  9.28  9.28  8.21  573878  515968665.0
#
#          振幅    涨跌幅   涨跌额   换手率
# 0     43.18  78.98  1.39  0.03
# 1      0.00  14.60  0.46  0.02
# 2      0.00  13.85  0.50  0.01
# 3      0.00  13.38  0.55  0.01
# 4      0.00  13.09  0.61  0.04
# ...     ...    ...   ...   ...
# 1821   0.00  10.07  0.58  0.99
# 1822   0.00   9.94  0.63  0.79
# 1823   0.00  10.04  0.70  3.71
# 1824   0.00  10.04  0.77  1.22
# 1825  12.68   9.95  0.84  8.62
#
# [1826 rows x 13 columns]

# %%
one.columns = ['name', 'code','date', 'open', 'close','high', 'low', 'volume', 'amount', 'amplitude','ratio', 'changed', 'turnover']
one
# Out:
#       name    code        date  open  close  high   low  volume       amount  \
# 0     国芳集团  601086  2017-09-29  2.39   3.15  3.15  2.39     493     221954.0
# 1     国芳集团  601086  2017-10-09  3.61   3.61  3.61  3.61     349     174839.0
# 2     国芳集团  601086  2017-10-10  4.11   4.11  4.11  4.11     196     107996.0
# 3     国芳集团  601086  2017-10-11  4.66   4.66  4.66  4.66     217     131502.0
# 4     国芳集团  601086  2017-10-12  5.27   5.27  5.27  5.27     682     455174.0
# ...    ...     ...         ...   ...    ...   ...   ...     ...          ...
# 1821  国芳集团  601086  2025-04-08  6.34   6.34  6.34  6.34   65748   41684232.0
# 1822  国芳集团  601086  2025-04-09  6.97   6.97  6.97  6.97   52318   36465646.0
# 1823  国芳集团  601086  2025-04-10  7.67   7.67  7.67  7.67  246827  189316041.0
# 1824  国芳集团  601086  2025-04-11  8.44   8.44  8.44  8.44   81569   68844236.0
# 1825  国芳集团  601086  2025-04-14  8.44   9.28  9.28  8.21  573878  515968665.0
#
#       amplitude  ratio  changed  turnover
# 0         43.18  78.98     1.39      0.03
# 1          0.00  14.60     0.46      0.02
# 2          0.00  13.85     0.50      0.01
# 3          0.00  13.38     0.55      0.01
# 4          0.00  13.09     0.61      0.04
# ...         ...    ...      ...       ...
# 1821       0.00  10.07     0.58      0.99
# 1822       0.00   9.94     0.63      0.79
# 1823       0.00  10.04     0.70      3.71
# 1824       0.00  10.04     0.77      1.22
# 1825      12.68   9.95     0.84      8.62
#
# [1826 rows x 13 columns]

# %%
sub.query("traded_cap > 1e10 and amount > 3e8")
# Out:
#         code  name  ratio  turnover        amount    vr   price  p_price  \
# 10    300723   一品红  19.30      6.89  1.154680e+09  1.63   41.97    35.18
# 27    832982  锦波生物  11.50      3.67  6.123168e+08  1.21  378.00   339.01
# 62    002675  东诚药业  10.03      3.06  3.208230e+08  2.29   14.26    12.96
# 67    002487  大金重工  10.02      2.52  3.969683e+08  1.42   25.04    22.76
# 69    601020  华钰矿业  10.02      7.21  1.131543e+09  0.72   19.76    17.96
# ...      ...   ...    ...       ...           ...   ...     ...      ...
# 5360  002028  思源电气  -3.89      1.89  8.267624e+08  1.46   71.60    74.50
# 5365  300627  华测导航  -4.17      2.03  3.740978e+08  0.96   39.80    41.53
# 5367  688385  复旦微电  -4.20      2.87  7.826027e+08  0.91   50.16    52.36
# 5368  002653   海思科  -4.28      1.59  3.880939e+08  1.20   45.42    47.45
# 5381  603129  春风动力  -5.46      2.83  6.660200e+08  1.18  151.45   160.20
#
#         high     low    open  changed     dpe  volume          cap  \
# 10     42.22   35.33   36.00     6.79  -57.67  291175  18957545389
# 27    378.00  333.33  338.99    38.99   34.21   16836  33457460400
# 62     14.26   13.09   13.15     1.30   63.97  227230  11758734753
# 67     25.04   24.60   24.60     2.28   33.70  158842  15969243699
# 69     19.76   18.09   18.09     1.80   79.44  591418  16202502432
# ...      ...     ...     ...      ...     ...     ...          ...
# 5360   74.75   70.76   74.68    -2.90   26.64  114532  55582844364
# 5365   41.77   39.75   41.51    -1.73   38.09   92369  21868614425
# 5367   52.39   50.02   52.09    -2.20   71.96  154089  41202793368
# 5368   46.99   44.60   46.75    -2.03  128.63   85403  50866674197
# 5381  160.20  150.60  160.03    -8.75   16.03   43125  23107887061
#
#        traded_cap market        date
# 10    17745710030     深A  2025-04-14
# 27    17346828240     深A  2025-04-14
# 62    10600655754     深A  2025-04-14
# 67    15798243461     深A  2025-04-14
# 69    16202502432     沪A  2025-04-14
# ...           ...    ...         ...
# 5360  43297961881     深A  2025-04-14
# 5365  18079541194     深A  2025-04-14
# 5367  26940800568     沪A  2025-04-14
# 5368  24337264974     深A  2025-04-14
# 5381  23107887061     沪A  2025-04-14
#
# [655 rows x 18 columns]

# %%
o2 = get_one('688388')
o2
# Out:
#       name    code        date   open  close   high    low  volume  \
# 0     嘉元科技  688388  2019-07-22  45.75  39.07  52.17  23.72  402094
# 1     嘉元科技  688388  2019-07-23  32.17  35.01  37.85  31.46  165822
# 2     嘉元科技  688388  2019-07-24  35.46  38.29  38.58  35.46  179648
# 3     嘉元科技  688388  2019-07-25  39.20  40.73  43.10  39.19  201243
# 4     嘉元科技  688388  2019-07-26  41.10  39.80  44.23  39.73  198737
# ...    ...     ...         ...    ...    ...    ...    ...     ...
# 1384  嘉元科技  688388  2025-04-08  15.00  15.48  16.24  15.00  111292
# 1385  嘉元科技  688388  2025-04-09  15.30  15.62  15.81  13.50  128757
# 1386  嘉元科技  688388  2025-04-10  16.48  16.13  17.04  16.08  108232
# 1387  嘉元科技  688388  2025-04-11  16.30  17.28  17.57  16.22  133395
# 1388  嘉元科技  688388  2025-04-14  17.68  18.27  18.35  17.68   94486
#
#             amount  amplitude   ratio  changed  turnover
# 0     2.111280e+09     151.41  107.93    20.28     76.10
# 1     8.515070e+08      16.36  -10.39    -4.06     31.38
# 2     9.758346e+08       8.91    9.37     3.28     34.00
# 3     1.197895e+09      10.21    6.37     2.44     38.09
# 4     1.216335e+09      11.05   -2.28    -0.93     37.61
# ...            ...        ...     ...      ...       ...
# 1384  1.729183e+08       7.91   -1.28    -0.20      2.61
# 1385  1.893228e+08      14.92    0.90     0.14      3.02
# 1386  1.794541e+08       6.15    3.27     0.51      2.54
# 1387  2.291449e+08       8.37    7.13     1.15      3.13
# 1388  1.712168e+08       3.88    5.73     0.99      2.22
#
# [1389 rows x 13 columns]

# %%
o2
# Out:
#       name    code        date   open  close   high    low  volume  \
# 0     嘉元科技  688388  2019-07-22  45.75  39.07  52.17  23.72  402094
# 1     嘉元科技  688388  2019-07-23  32.17  35.01  37.85  31.46  165822
# 2     嘉元科技  688388  2019-07-24  35.46  38.29  38.58  35.46  179648
# 3     嘉元科技  688388  2019-07-25  39.20  40.73  43.10  39.19  201243
# 4     嘉元科技  688388  2019-07-26  41.10  39.80  44.23  39.73  198737
# ...    ...     ...         ...    ...    ...    ...    ...     ...
# 1384  嘉元科技  688388  2025-04-08  15.00  15.48  16.24  15.00  111292
# 1385  嘉元科技  688388  2025-04-09  15.30  15.62  15.81  13.50  128757
# 1386  嘉元科技  688388  2025-04-10  16.48  16.13  17.04  16.08  108232
# 1387  嘉元科技  688388  2025-04-11  16.30  17.28  17.57  16.22  133395
# 1388  嘉元科技  688388  2025-04-14  17.68  18.27  18.35  17.68   94486
#
#             amount  amplitude   ratio  changed  turnover
# 0     2.111280e+09     151.41  107.93    20.28     76.10
# 1     8.515070e+08      16.36  -10.39    -4.06     31.38
# 2     9.758346e+08       8.91    9.37     3.28     34.00
# 3     1.197895e+09      10.21    6.37     2.44     38.09
# 4     1.216335e+09      11.05   -2.28    -0.93     37.61
# ...            ...        ...     ...      ...       ...
# 1384  1.729183e+08       7.91   -1.28    -0.20      2.61
# 1385  1.893228e+08      14.92    0.90     0.14      3.02
# 1386  1.794541e+08       6.15    3.27     0.51      2.54
# 1387  2.291449e+08       8.37    7.13     1.15      3.13
# 1388  1.712168e+08       3.88    5.73     0.99      2.22
#
# [1389 rows x 13 columns]

# %%
o24 = o2.query("date >= '2024'").reset_index().copy()
import pandas_ta as ta
o24['e13'] = ta.ema(o24.close, 13)
o24['e21'] = ta.ema(o24.close, 21)
o24['e70'] = ta.ema(o24.close, 70)
o24['e84'] = ta.ema(o24.close, 84)

o24[::-1]
# Out:
#      index  name    code        date   open  close   high    low  volume  \
# 307   1388  嘉元科技  688388  2025-04-14  17.68  18.27  18.35  17.68   94486
# 306   1387  嘉元科技  688388  2025-04-11  16.30  17.28  17.57  16.22  133395
# 305   1386  嘉元科技  688388  2025-04-10  16.48  16.13  17.04  16.08  108232
# 304   1385  嘉元科技  688388  2025-04-09  15.30  15.62  15.81  13.50  128757
# 303   1384  嘉元科技  688388  2025-04-08  15.00  15.48  16.24  15.00  111292
# ..     ...   ...     ...         ...    ...    ...    ...    ...     ...
# 4     1085  嘉元科技  688388  2024-01-08  18.76  18.37  19.00  18.36   37208
# 3     1084  嘉元科技  688388  2024-01-05  19.18  18.81  19.64  18.69   36011
# 2     1083  嘉元科技  688388  2024-01-04  19.54  19.14  19.61  19.07   28451
# 1     1082  嘉元科技  688388  2024-01-03  19.61  19.54  19.76  19.40   24198
# 0     1081  嘉元科技  688388  2024-01-02  20.28  19.66  20.32  19.65   36287
#
#           amount  amplitude  ratio  changed  turnover        e13        e21  \
# 307  171216825.0       3.88   5.73     0.99      2.22  17.651826  17.897686
# 306  229144930.0       8.37   7.13     1.15      3.13  17.548797  17.860454
# 305  179454094.0       6.15   3.27     0.51      2.54  17.593596  17.918500
# 304  189322752.0      14.92   0.90     0.14      3.02  17.837529  18.097350
# 303  172918330.0       7.91  -1.28    -0.20      2.61  18.207117  18.345085
# ..           ...        ...    ...      ...       ...        ...        ...
# 4     69320068.0       3.40  -2.34    -0.44      0.90        NaN        NaN
# 3     68783572.0       4.96  -1.72    -0.33      0.87        NaN        NaN
# 2     54737460.0       2.76  -2.05    -0.40      0.69        NaN        NaN
# 1     47357202.0       1.83  -0.61    -0.12      0.59        NaN        NaN
# 0     72055902.0       3.31  -3.01    -0.61      0.88        NaN        NaN
#
#            e70        e84
# 307  17.054114  16.724167
# 306  17.018871  16.686918
# 305  17.011302  16.672627
# 304  17.036847  16.685702
# 303  17.077915  16.711382
# ..         ...        ...
# 4          NaN        NaN
# 3          NaN        NaN
# 2          NaN        NaN
# 1          NaN        NaN
# 0          NaN        NaN
#
# [308 rows x 18 columns]

# %%
# Out:
#      index  name    code        date   open  close   high    low  volume  \
# 0     1081  嘉元科技  688388  2024-01-02  20.28  19.66  20.32  19.65   36287
# 1     1082  嘉元科技  688388  2024-01-03  19.61  19.54  19.76  19.40   24198
# 2     1083  嘉元科技  688388  2024-01-04  19.54  19.14  19.61  19.07   28451
# 3     1084  嘉元科技  688388  2024-01-05  19.18  18.81  19.64  18.69   36011
# 4     1085  嘉元科技  688388  2024-01-08  18.76  18.37  19.00  18.36   37208
# ..     ...   ...     ...         ...    ...    ...    ...    ...     ...
# 303   1384  嘉元科技  688388  2025-04-08  15.00  15.48  16.24  15.00  111292
# 304   1385  嘉元科技  688388  2025-04-09  15.30  15.62  15.81  13.50  128757
# 305   1386  嘉元科技  688388  2025-04-10  16.48  16.13  17.04  16.08  108232
# 306   1387  嘉元科技  688388  2025-04-11  16.30  17.28  17.57  16.22  133395
# 307   1388  嘉元科技  688388  2025-04-14  17.68  18.27  18.35  17.68   94486
#
#           amount  amplitude  ratio  changed  turnover        e13        e21  \
# 0     72055902.0       3.31  -3.01    -0.61      0.88        NaN        NaN
# 1     47357202.0       1.83  -0.61    -0.12      0.59        NaN        NaN
# 2     54737460.0       2.76  -2.05    -0.40      0.69        NaN        NaN
# 3     68783572.0       4.96  -1.72    -0.33      0.87        NaN        NaN
# 4     69320068.0       3.40  -2.34    -0.44      0.90        NaN        NaN
# ..           ...        ...    ...      ...       ...        ...        ...
# 303  172918330.0       7.91  -1.28    -0.20      2.61  18.207117  18.345085
# 304  189322752.0      14.92   0.90     0.14      3.02  17.837529  18.097350
# 305  179454094.0       6.15   3.27     0.51      2.54  17.593596  17.918500
# 306  229144930.0       8.37   7.13     1.15      3.13  17.548797  17.860454
# 307  171216825.0       3.88   5.73     0.99      2.22  17.651826  17.897686
#
#            e70        e84  golden
# 0          NaN        NaN       0
# 1          NaN        NaN       0
# 2          NaN        NaN       0
# 3          NaN        NaN       0
# 4          NaN        NaN       0
# ..         ...        ...     ...
# 303  17.077915  16.711382       0
# 304  17.036847  16.685702       0
# 305  17.011302  16.672627       0
# 306  17.018871  16.686918       0
# 307  17.054114  16.724167       0
#
# [308 rows x 19 columns]
